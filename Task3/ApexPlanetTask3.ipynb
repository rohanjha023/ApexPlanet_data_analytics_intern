# %% [markdown]
# # Task 3: Deep-Dive Analysis & Interactive Dashboard
#
# **Objective**- To perform in-depth data analysis, identify key business insights, and build an interactive dashboard for decision-making.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/task1_cleaned_superstore.csv')
df.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           category  sub_category  \
# 0        Furniture     Bookcases
# ...

# %%
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Validation
#
# The dataset used in this analysis was already cleaned in previous tasks.
#
# However, a quick validation was performed to ensure:
# - No missing values are present
# - No duplicate records exist
#
# The dataset is clean and ready for analysis.

# %% [markdown]
# **KPI Section**

# %%
total_revenue = df['sales'].sum()
total_profit = df['profit'].sum()
total_orders = df.shape[0]
average_order_value = df['sales'].mean()

print("Total Revenue:", total_revenue)
print("Total Profit:", total_profit)
print("Total Orders:", total_orders)
print("Average Order Value:", average_order_value)
# Out:
# Total Revenue: 2297200.8603000003
# Total Profit: 286397.0217
# Total Orders: 9994
# Average Order Value: 229.85800083049833

# %% [markdown]
# ## Key Performance Indicators (KPIs)
#
# - Total Revenue: Overall sales generated from all transactions
# - Total Profit: Total profit earned by the business
# - Total Orders: Total number of transactions/orders
# - Average Order Value: Average revenue per order

# %% [markdown]
# # **Deep Dive Analysis**

# %% [markdown]
# **Monthly Sales Trend**

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

monthly_sales = df.groupby(df['order_date'].dt.month)['sales'].sum()

monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ## Monthly Sales Analysis
#
# This analysis shows how sales vary across different months and helps identify seasonal trends.

# %% [markdown]
# **Category Analysis**

# %%
category_sales = df.groupby('category')['sales'].sum()

category_sales.plot(kind='bar')
plt.title("Sales by Category")
plt.show()

# %% [markdown]
# ## Category-wise Analysis
#
# This analysis identifies which category contributes the most to total revenue.

# %% [markdown]
# **Top Products**

# %%
top_products = df.groupby('product_name')['sales'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind='bar')
plt.title("Top 10 Products")
plt.show()

# %% [markdown]
# ## Top Products Analysis
#
# Top-performing products are identified based on highest sales contribution.

# %% [markdown]
# ## Observations
#
# 1. The total revenue generated is ₹2,297,200, indicating strong overall business performance.
#
# 2. The total profit is ₹286,400, showing that the business is operating profitably.
#
# 3. Sales show a peak in the month of November, indicating high customer demand during this period, possibly due to seasonal factors or festive sales.
#
# 4. The category "Technology" contributes the highest revenue among all categories, making it the most significant segment for the business.
#
# 5. The top-selling product is "Canon ImageCLASS 2200 Advanced Copier", generating the highest sales among all products.
#
# 6. The sales trend shows a gradual increase over time, indicating consistent business growth.

# %%
df.to_csv('/content/final_data.csv', index=False)

# %% [markdown]
# # **Dashboard**

# %% [markdown]
# ![Screenshot 2026-04-19 162718.png](data:image/png;base64,...)

# %% [markdown]
# ## Observations
#
# 1. The total revenue generated is ₹2.30M, indicating strong overall business performance.
#
# 2. The total profit is ₹286.40K, showing that the business is highly profitable.
#
# 3. Sales show a peak in the month of November, indicating high customer demand during this period.
#
# 4. The category "Technology" contributes the highest revenue among all categories.
#
# 5. The top-selling product is "Canon imageCLASS 2200 Advanced Copier".
#
# 6. Sales trend shows a gradual increase over time, especially towards the end of the year.

# %% [markdown]
# ## Conclusion
#
# The dashboard provides comprehensive insights into business performance through key metrics such as revenue, profit, and sales trends. It highlights that the Technology category and high-value products significantly contribute to overall revenue. Additionally, the increasing sales trend towards the end of the year suggests strong seasonal demand, which can be leveraged for future business strategies.
